# %% [markdown]
# <a href="https://colab.research.google.com/github/salsafadilah/Deteksi-APD/blob/main/Deteksi_APD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
home ='/content/drive/MyDrive/Colab Notebooks'

# %%
# %cd {home}
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vEHmH7ySdxecdJ2lZ8hd")
project = rf.workspace("trial-g0z45").project("eep_detection-u9bbd-nvlnd")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to EEP_Detection-1 in yolov8:: 100%|██████████| 15531/15531 [02:59<00:00, 86.46it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s.pt')

# %%
result=model.train(
    data="/content/drive/MyDrive/Colab Notebooks/EEP_Detection-1/data.yaml",
    epochs=30,
    batch=10,
    imgsz=640,
    save=True,
    device=0,
    project='/content/drive/MyDrive/Colab Notebooks/EEP_Detection-1',
    name='train'
)
# Out:
# Ultralytics 8.4.70 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
